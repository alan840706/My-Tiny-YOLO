# %% [markdown]
# <a href="https://colab.research.google.com/github/alan840706/My-Tiny-YOLO/blob/master/%E5%AF%A6%E9%A9%972.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd ..
# !git clone https://github.com/alan840706/darkflow   #label.txt  更改 class 並移到當前目錄           
# !git clone https://github.com/alan840706/makeYOLOv3 
# !git clone https://github.com/alan840706/Tinier-YOLO   #train.py 更改 class
from google.colab import drive
drive.mount('/gdrive')
# !gdown --id '1blhzGGOCN1qeheQOyJaVKOBFDvpyjufu' --output darknet.zip
# !gdown --id '1by-4rWtY6-Gp9JTXX0lyJkdDc84a5d1w' --output images.zip
# !gdown --id '1GWPIAZlWFSgLSVDybH7NLBQP-9DMfsox' --output labels.zip
import zipfile
local_zip = 'images.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()
local_zip = 'labels.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()
local_zip = 'darknet.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()


# !pip install wget
# !python makeYOLOv3/train.py
# !python makeYOLOv3/kmean.py
# Out:
# /
# fatal: destination path 'darkflow' already exists and is not an empty directory.
# fatal: destination path 'makeYOLOv3' already exists and is not an empty directory.
# fatal: destination path 'Tinier-YOLO' already exists and is not an empty directory.
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# Downloading...
# From: https://drive.google.com/uc?id=1by-4rWtY6-Gp9JTXX0lyJkdDc84a5d1w
# To: /images.zip
# 7.24MB [00:00, 23.0MB/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python2.7/dist-packages/gdown/cli.py", line 61, in main
#     quiet=args.quiet,
#   File "/usr/local/lib/python2.7/dist-packages/gdown/download.py", line 52, in download
#     res = sess.get(url, stream=True)
#
# ...
# Using TensorFlow backend.
# ...

# %%
# !chmod 755 /content/darknet
# !/gdrive/My\ Drive/darknet/darknet detector train cfg.person/obj.data cfg.person/yolov2-tiny_dep.cfg # cfg.person/weights/yolov2-tiny_1000.weights #-dont_show   #cfg.person/weights/yolov2-tiny_0_last.weights
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Loaded: 0.000045 seconds
# Region Avg IOU: 0.732936, Class: 1.000000, Obj: 0.809887, No Obj: 0.004018, Avg Recall: 0.970588,  count: 34
# Region Avg IOU: 0.655504, Class: 1.000000, Obj: 0.843250, No Obj: 0.004920, Avg Recall: 0.833333,  count: 42
# 25366: 3.827890, 5.585347 avg, 0.001000 rate, 0.789425 seconds, 1623424 images
# Loaded: 0.000057 seconds
# Region Avg IOU: 0.694062, Class: 1.000000, Obj: 0.742856, No Obj: 0.004274, Avg Recall: 0.846154,  count: 39
# Region Avg IOU: 0.690026, Class: 1.000000, Obj: 0.847847, No Obj: 0.004553, Avg Recall: 0.888889,  count: 36
# 25367: 5.172055, 5.544018 avg, 0.001000 rate, 0.863951 seconds, 1623488 images
# Loaded: 0.000052 seconds
# Region Avg IOU: 0.664334, Class: 1.000000, Obj: 0.845742, No Obj: 0.004848, Avg Recall: 0.820513,  count: 39
# Region Avg IOU: 0.743890, Class: 1.000000, Obj: 0.821319, No Obj: 0.004734, Avg Recall: 1.000000,  count: 33
# ...

# %%
# !chmod 755 /gdrive/My\ Drive/darknet/darknet
# !/gdrive/My\ Drive/darknet/darknet detector train cfg.person/obj.data cfg.person/yolov2-tiny_dep.cfg

# %%
# !chmod 755 /gdrive/My\ Drive/darknet/darknet
# !/gdrive/My\ Drive/darknet/darknet detector train cfg.person/obj.data cfg.person/yolov2-tiny_dep.cfg

# %%
# %cd ..
# !chmod 755 cfg.person/darknet_1
# !cfg.person/darknet_1 detector test cfg.person/obj.data cfg.person/yolov2-tiny.cfg cfg.person/weights/yolov2-tiny_40000.weights cfg.person/train.txt  # 新增檔案夾result_img
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# person: 100%
# save result_img/2547 successfully!
# ...

# %%
# %cd ..
# !pip3 install tensorflow==1.12 #
# %cd darkflow
# !pip install -e  /darkflow
# !flow --h
# %cd ..

# !flow --model cfg.person/yolov3-tiny.cfg --load cfg.person/weights/yolov3-tiny_29000.weights  --savepb   

# !tflite_convert \
    --output_file=yolov3-tiny.tflite \
    --graph_def_file=built_graph/yolov3-tiny.pb \
    --input_arrays=input \
    --output_arrays=output


# !git clone https://github.com/sipeed/Maix_Toolbox.git    


# %cd Maix_Toolbox 
# !mkdir -p ncc
# !mkdir -p workspace
# !mkdir -p images
# !mkdir -p log
# %cd ncc
#!wget https://github.com/kendryte/nncase/releases/download/v0.2.0-beta2/ncc_linux_x86_64.tar.xz  
# !wget https://github.com/kendryte/nncase/releases/download/v0.1.0-rc5/ncc-linux-x86_64.tar.xz
# !tar -Jxf ncc-linux-x86_64.tar.xz 
# !rm -Jxf ncc-linux-x86_64.tar.xz 

# %cd .. 
# %cd ..
# Out:
# /
# ...
#      |████████████████████████████████| 83.1MB 56kB/s
# ...
#      |████████████████████████████████| 3.1MB 57.7MB/s
# ...
#   Found existing installation: tensorboard 2.2.2
#     Uninstalling tensorboard-2.2.2:
#       Successfully uninstalled tensorboard-2.2.2
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# ...
# /darkflow
# Obtaining file:///darkflow
# ...
#   Running setup.py develop for darkflow
# ...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# ...

# %%
#!./Maix_Toolbox/ncc/ncc compile yolov3-tiny.tflite yolov3-tiny.kmodel -i tflite -o kmodel -t k210 --dataset ./Maix_Toolbox/images
# !./Maix_Toolbox/ncc/ncc  yolov3-tiny.tflite yolov3-tiny.kmodel -i tflite -o k210model  --dataset ./Maix_Toolbox/images
# Out:
# Fatal: Dimensions must be equal.
# System.InvalidOperationException: Dimensions must be equal.
#    at NnCase.Converter.Model.InputConnector.SetConnection(OutputConnector from) in D:\Work\Repository\nncase\src\NnCase.Converter\Model\InputConnector.cs:line 32
#    at NnCase.Converter.Converters.TfLiteToGraphConverter.Convert() in D:\Work\Repository\nncase\src\NnCase.Converter\Converters\TfLiteToGraphConverter.cs:line 34
#    at NnCase.Cli.Program.Main(String[] args) in D:\Work\Repository\nncase\src\NnCase.Cli\Program.cs:line 113
#    at NnCase.Cli.Program.<Main>(String[] args)

# %%
######################################                       待測試                               ######################################################

# %%
# !pip3 install tensorflow==1.12 #
# Out:
# ...
#      |████████████████████████████████| 83.1MB 66kB/s
# ...
#      |████████████████████████████████| 3.1MB 55.6MB/s
# ...
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow 2.2.0
#     Uninstalling tensorflow-2.2.0:
#       Successfully uninstalled tensorflow-2.2.0
# ...

# %%
# !git clone https://github.com/BBuf/cv_tools
# Out:
# Cloning into 'cv_tools'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 28 (delta 4), reused 24 (delta 3), pack-reused 0
# Unpacking objects: 100% (28/28), done.

# %%
# !python3 tensorflow-yolo-v3/convert_weights_pb.py \
    --class_names cfg.person/obj.names \
    --weights_file cfg.person/weights/yolov3-tiny_last.weights \
    --data_format NHWC \
    --tiny \
    --output_graph ./frozen_tiny_yolo_v3.pb
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import tensorflow as tf
Graph = tf.compat.v1.GraphDef()    
File = open("obj.pb","rb")
Graph.ParseFromString(File.read())

for Layer in Graph.node:
    print(Layer.name)

# %%
import tensorflow as tf
gf = tf.GraphDef()   
m_file = open('yolov3-tiny.pb','rb')
gf.ParseFromString(m_file.read())

with open('somefile.txt', 'a') as the_file:
    for n in gf.node:
        the_file.write(n.name+'\n')

file = open('somefile.txt','r')
data = file.readlines()
print ("output name = ")
print (data[len(data)-1])

print ("Input name = ")
file.seek ( 0 )
print (file.readline())

# %%
# !git clone https://github.com/AlexeyAB/darknet 
# %cd darknet

# 修改 Darknet 設定，符合 Colab 環境
# !sed -i "s/GPU=0/GPU=1/g" Makefile
# !sed -i "s/CUDNN=0/CUDNN=1/g" Makefile
# !sed -i "s/OPENCV=0/OPENCV=1/g" Makefile
# 編譯
# !make
# !ln -fs /gdrive/My\ Drive/darknet /app
# !tar -xzvf /app/cuDNN/cudnn-10.0-linux-x64-v7.6.5.32.tgz -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h
# 將編譯完成的執行檔複製回 Google Drive
# !cp ./darknet /app
# !cp ./darknet /content/darknet
# %cd ..

# %%
# !git clone https://github.com/sipeed/Maix_Toolbox.git    


# %cd Maix_Toolbox 
# !mkdir -p ncc
# !mkdir -p workspace
# !mkdir -p images
# !mkdir -p log
# %cd ncc
#!wget https://github.com/kendryte/nncase/releases/download/v0.2.0-beta2/ncc_linux_x86_64.tar.xz  
# !wget https://github.com/kendryte/nncase/releases/download/v0.1.0-rc5/ncc-linux-x86_64.tar.xz
# !tar -Jxf ncc-linux-x86_64.tar.xz 
# !rm -Jxf ncc-linux-x86_64.tar.xz 

# %cd .. 
# %cd ..
# Out:
# Cloning into 'Maix_Toolbox'...
# remote: Enumerating objects: 34, done.
# remote: Total 34 (delta 0), reused 0 (delta 0), pack-reused 34
# Unpacking objects: 100% (34/34), done.
# /Maix_Toolbox
# /Maix_Toolbox/ncc
# --2020-05-15 09:04:04--  https://github.com/kendryte/nncase/releases/download/v0.2.0-beta2/ncc_linux_x86_64.tar.xz
# Resolving github.com (github.com)... 140.82.118.4
# Connecting to github.com (github.com)|140.82.118.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !tflite_convert \
    --output_file=yolov3-tiny.tflite \
    --graph_def_file=frozen_tiny_yolo_v3.pb \
    --input_arrays=inputs \
    --output_arrays=output
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !git clone https://github.com/mystic123/tensorflow-yolo-v3
# Out:
# Cloning into 'tensorflow-yolo-v3'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 219 (delta 1), reused 2 (delta 0), pack-reused 213
# Receiving objects: 100% (219/219), 59.90 KiB | 659.00 KiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# !flow --model cfg.person/yolov3-tiny.cfg --load cfg.person/weights/yolov3-tiny_last.weights  --savepb
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
